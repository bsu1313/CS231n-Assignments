# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/cs231n/assignments'
# Out:
# /content/drive/MyDrive/cs231n/assignments

# %%
# !echo "# CS231n_Assignments" >> README.md
# !git init
# !git config --global user.email "bsu1313@naver.com"
# !git config --global user.name "bsu1313"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://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@github.com/bsu1313/cs231n-assignments.git
# !git push -u origin main
# Out:
# Initialized empty Git repository in /content/drive/My Drive/cs231n/assignments/.git/
# [master (root-commit) c463782] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# Counting objects: 3, done.
# Writing objects: 100% (3/3), 226 bytes | 75.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/bsu1313/CS231n-Assignments.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main 9724660] setup
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (95%)
# Counting objects: 227, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (222/222), done.
# error: RPC failed; curl 55 Failed sending data to the peer
# fatal: The remote end hung up unexpectedly
# Writing objects: 100% (227/227), 1.13 GiB | 22.58 MiB/s, done.
# Total 227 (delta 55), reused 2 (delta 0)
# fatal: The remote end hung up unexpectedly
# Everything up-to-date

# %% [markdown]
# 아래 방법은 잘 안되는거 같아서 그냥 깃허브 경로만 복붙하니 위에 방법이 되었다.

# %%
# !git remote rm origin
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/cs231n/assignments' 
# replace with your Github username 
GIT_USERNAME = "bsu1313" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "CS231n_Assignments" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/cs231n/assignments
# mkdir: cannot create directory ‘/content/drive/MyDrive/cs231n/assignments’: File exists
# GIT_PATH:  https://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@github.com/bsu1313/CS231n_Assignment.git

# %%
# %cd "{PROJECT_PATH}"    # Change directory to the location defined in project_path
# !git clone "{GIT_PATH}" . # clone the github repository
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/cs231n/assignments # Change directory to the location defined in project_path'
# /content
# fatal: destination path '.' already exists and is not an empty directory.
